# %%
import pandas as pd

# %%
surveys=pd.read_csv("/home/john/Downloads/surveys.csv")

# %%
surveys
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 10            11      7   16  1977        5         DS    F             53.0
# ...

# %%
species=species_df = pd.read_csv("~/Downloads/species.csv",
                         keep_default_na=False, na_values=[""])

# %%
species
# Out:
#    species_id             genus          species                   taxa
# 0          AB        Amphispiza        bilineata                   Bird
# 1          AH  Ammospermophilus          harrisi    Rodent-not censused
# 2          AS        Ammodramus       savannarum                   Bird
# 3          BA           Baiomys          taylori                 Rodent
# 4          CB   Campylorhynchus  brunneicapillus                   Bird
# 5          CM       Calamospiza      melanocorys                   Bird
# 6          CQ        Callipepla         squamata                   Bird
# 7          CS          Crotalus       scutalatus                Reptile
# 8          CT     Cnemidophorus           tigris                Reptile
# 9          CU     Cnemidophorus        uniparens                Reptile
# 10         CV          Crotalus          viridis                Reptile
# 11         DM         Dipodomys         merriami                 Rodent
# ...

# %%
survey_sub = surveys.head(10)
survey_sub_last10 = surveys.tail(10)
survey_sub_last10=survey_sub_last10.reset_index(drop=True)

# %%
vertical_stack = pd.concat([survey_sub, survey_sub_last10], axis=0)

# %%
vertical_stack
# Out:
#    record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL    M             32.0
# 1          2      7   16  1977        3         NL    M             33.0
# 2          3      7   16  1977        2         DM    F             37.0
# 3          4      7   16  1977        7         DM    M             36.0
# 4          5      7   16  1977        3         DM    M             35.0
# 5          6      7   16  1977        1         PF    M             14.0
# 6          7      7   16  1977        2         PE    F              NaN
# 7          8      7   16  1977        1         DM    M             37.0
# 8          9      7   16  1977        1         DM    F             34.0
# 9         10      7   16  1977        6         PF    F             20.0
# 0      35540     12   31  2002       15         PB    F             26.0
# 1      35541     12   31  2002       15         PB    F             24.0
# ...

# %%
vertical_stack.reset_index()
# Out:
#     index  record_id  month  day  year  plot_id species_id  sex  \
# 0       0          1      7   16  1977        2         NL    M
# 1       1          2      7   16  1977        3         NL    M
# 2       2          3      7   16  1977        2         DM    F
# 3       3          4      7   16  1977        7         DM    M
# 4       4          5      7   16  1977        3         DM    M
# 5       5          6      7   16  1977        1         PF    M
# 6       6          7      7   16  1977        2         PE    F
# 7       7          8      7   16  1977        1         DM    M
# 8       8          9      7   16  1977        1         DM    F
# 9       9         10      7   16  1977        6         PF    F
# 10      0      35540     12   31  2002       15         PB    F
# 11      1      35541     12   31  2002       15         PB    F
# 12      2      35542     12   31  2002       15         PB    F
# 13      3      35543     12   31  2002       15         PB    F
# ...

# %%
vertical_stack.to_csv('out.csv', index=False)

# %%
vertical_stack['wgt'].describe()
# Out:
# count    3528.000000
# mean       35.980442
# std        27.029138
# min         5.000000
# 25%        22.000000
# 50%        31.000000
# 75%        44.000000
# max       280.000000
# Name: wgt, dtype: float64

# %%
group=vertical_stack.groupby('sex')['wgt']

# %%
group

# %%
group.describe()
# Out:
#       count         mean       std     min     25%     50%     75%     max
# sex
# F    1892.0  2001.607294  0.488481  2001.0  2001.0  2002.0  2002.0  2002.0
# M    1723.0  2001.568195  0.495471  2001.0  2001.0  2002.0  2002.0  2002.0

# %%
surveys2001=pd.read_csv("/home/john/Downloads/survey2001.csv", keep_default_na=False, na_values=[""])
surveys2002=pd.read_csv("/home/john/Downloads/survey2002.csv", keep_default_na=False, na_values=[""])

# %%
surveyst=pd.concat([surveys2001,surveys2002],axis=0, sort=False)

# %%
surveyst
# Out:
#       Unnamed: 0  record_id  month  day  year  plot species  sex    wgt  \
# 0          31710      31711      1   21  2001   1.0      PB    F   25.0
# 1          31711      31712      1   21  2001   1.0      DM    M   43.0
# 2          31712      31713      1   21  2001   1.0      PB    M   44.0
# 3          31713      31714      1   21  2001   1.0      DO    M   53.0
# 4          31714      31715      1   21  2001   2.0      OT    M   27.0
# 5          31715      31716      1   21  2001   2.0      RM    M   11.0
# 6          31716      31717      1   21  2001   2.0      NL    M  121.0
# 7          31717      31718      1   21  2001   2.0      DM    F   44.0
# 8          31718      31719      1   21  2001   2.0      PB    M   42.0
# 9          31719      31720      1   21  2001   2.0      PB    M   41.0
# 10         31720      31721      1   21  2001   2.0      NL    F  158.0
# 11         31721      31722      1   21  2001  12.0      DO    M   54.0
# ...

# %%
group=surveys.groupby('sex')

# %%
group['weight'].describe()
# Out:
#        count       mean        std  min   25%   50%   75%    max
# sex
# F    15303.0  42.170555  36.847958  4.0  20.0  34.0  46.0  274.0
# M    16879.0  42.995379  36.184981  4.0  20.0  39.0  49.0  280.0

# %%
t=surveys2001.groupby('sex')

# %%
t['wgt'].mean()
# Out:
# sex
# F    36.221914
# M    36.481844
# Name: wgt, dtype: float64

# %%
t.groupby('year')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-89-4db4dc949b07> in <module>()
# ----> 1 t.groupby('year')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     760             return self[attr]
#     761         if hasattr(self.obj, attr):
# --> 762             return self._make_wrapper(attr)
#     763
#     764         raise AttributeError("%r object has no attribute %r" %
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _make_wrapper(self, name)
#     797                    "using the 'apply' method".format(kind, name,
#     798                                                      type(self).__name__))
# --> 799             raise AttributeError(msg)
#     800
#     801         self._set_group_selection()
#
# ...

# %%
group.groupby('year')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-90-21b3f90b7c85> in <module>()
# ----> 1 group.groupby('year')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     760             return self[attr]
#     761         if hasattr(self.obj, attr):
# --> 762             return self._make_wrapper(attr)
#     763
#     764         raise AttributeError("%r object has no attribute %r" %
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _make_wrapper(self, name)
#     797                    "using the 'apply' method".format(kind, name,
#     798                                                      type(self).__name__))
# --> 799             raise AttributeError(msg)
#     800
#     801         self._set_group_selection()
#
# ...
